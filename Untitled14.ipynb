# %% [markdown]
# <a href="https://colab.research.google.com/github/Simransoni1/git-regex/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
brics=pd.read_csv('brics.csv',index_col=0)

# %%
brics
# Out:
#            country    capital    area  population
# Code
# BR          Brazil   Brasilia   8.516      200.40
# RU          Russia     Moscow  17.100      143.50
# IN           India  New Delhi   3.286     1252.00
# CH           China    Beijing   9.597     1357.00
# SA    South Africa   Pretoria   1.221       52.98

# %%
brics.shape
# Out:
# (5, 4)

# %%
brics.loc[["RU"]]
# Out:
#      country capital  area  population
# Code
# RU    Russia  Moscow  17.1       143.5

# %%
brics.loc[["RU","IN","SA"]]
# Out:
#            country    capital    area  population
# Code
# RU          Russia     Moscow  17.100      143.50
# IN           India  New Delhi   3.286     1252.00
# SA    South Africa   Pretoria   1.221       52.98

# %%
brics.loc[["RU","IN","SA"],["country","capital"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-1590750574.py in <cell line: 0>()
# ----> 1 brics.loc[["RU","IN","SA"],["country","capital"]]
#
# NameError: name 'brics' is not defined

# %%
import pandas as pd
brics=pd.read_csv('brics.csv',index_col=0)

# %%
brics.iloc[ :,[1,2]]
# Out:
#         capital    area
# Code
# BR     Brasilia   8.516
# RU       Moscow  17.100
# IN    New Delhi   3.286
# CH      Beijing   9.597
# SA     Pretoria   1.221

# %%
brics.iloc[[1,2],:]
# Out:
#      country    capital    area  population
# Code
# RU    Russia     Moscow  17.100       143.5
# IN     India  New Delhi   3.286      1252.0

# %%
brics.iloc[2:5,:]
# Out:
#            country    capital   area  population
# Code
# IN           India  New Delhi  3.286     1252.00
# CH           China    Beijing  9.597     1357.00
# SA    South Africa   Pretoria  1.221       52.98
